# %%
import pandas as pd

# %%
df = pd.read_csv("./data/data/data/indexData.csv")

# %%
df
# Out:
#        Index        Date         Open         High          Low        Close  \
# 0        NYA  1965-12-31   528.690002   528.690002   528.690002   528.690002
# 1        NYA  1966-01-03   527.210022   527.210022   527.210022   527.210022
# 2        NYA  1966-01-04   527.840027   527.840027   527.840027   527.840027
# 3        NYA  1966-01-05   531.119995   531.119995   531.119995   531.119995
# 4        NYA  1966-01-06   532.070007   532.070007   532.070007   532.070007
# ...      ...         ...          ...          ...          ...          ...
# 112452  N100  2021-05-27  1241.119995  1251.910034  1241.119995  1247.069946
# 112453  N100  2021-05-28  1249.469971  1259.209961  1249.030029  1256.599976
# 112454  N100  2021-05-31  1256.079956  1258.880005  1248.140015  1248.930054
# 112455  N100  2021-06-01  1254.609985  1265.660034  1254.609985  1258.579956
# 112456  N100  2021-06-02  1258.489990  1263.709961  1258.239990  1263.619995
#
#           Adj Close       Volume
# ...

# %%
filename = "./data/data/data/indexData.csv"

# %%
f = open(filename,"r")
lines = f.readlines()

# %%
lines
# Out:
# ['\ufeffIndex,Date,Open,High,Low,Close,Adj Close,Volume\n',
#  'NYA,1965-12-31,528.690002,528.690002,528.690002,528.690002,528.690002,0\n',
#  'NYA,1966-01-03,527.210022,527.210022,527.210022,527.210022,527.210022,0\n',
#  'NYA,1966-01-04,527.840027,527.840027,527.840027,527.840027,527.840027,0\n',
#  'NYA,1966-01-05,531.119995,531.119995,531.119995,531.119995,531.119995,0\n',
#  'NYA,1966-01-06,532.070007,532.070007,532.070007,532.070007,532.070007,0\n',
#  'NYA,1966-01-07,532.599976,532.599976,532.599976,532.599976,532.599976,0\n',
#  'NYA,1966-01-10,533.869995,533.869995,533.869995,533.869995,533.869995,0\n',
#  'NYA,1966-01-11,534.289978,534.289978,534.289978,534.289978,534.289978,0\n',
#  'NYA,1966-01-12,533.340027,533.340027,533.340027,533.340027,533.340027,0\n',
#  'NYA,1966-01-13,534.400024,534.400024,534.400024,534.400024,534.400024,0\n',
#  'NYA,1966-01-14,535.450012,535.450012,535.450012,535.450012,535.450012,0\n',
# ...

# %%
f.close()

# %%
dataTable = [] 
for line in lines:
    line2 = line.replace("\n", "") 
    dataFields = line2.split(",")
    dataTable.append(dataFields)

# %%
dataTable = []
for line in lines:
    line3 = line.replace(",", "")
    dataFields = line3.split(",")
    dataTable.append(dataFields)

# %%
dataTable
# Out:
# [['\ufeffIndexDateOpenHighLowCloseAdj CloseVolume\n'],
#  ['NYA1965-12-31528.690002528.690002528.690002528.690002528.6900020\n'],
#  ['NYA1966-01-03527.210022527.210022527.210022527.210022527.2100220\n'],
#  ['NYA1966-01-04527.840027527.840027527.840027527.840027527.8400270\n'],
#  ['NYA1966-01-05531.119995531.119995531.119995531.119995531.1199950\n'],
#  ['NYA1966-01-06532.070007532.070007532.070007532.070007532.0700070\n'],
#  ['NYA1966-01-07532.599976532.599976532.599976532.599976532.5999760\n'],
#  ['NYA1966-01-10533.869995533.869995533.869995533.869995533.8699950\n'],
#  ['NYA1966-01-11534.289978534.289978534.289978534.289978534.2899780\n'],
#  ['NYA1966-01-12533.340027533.340027533.340027533.340027533.3400270\n'],
#  ['NYA1966-01-13534.400024534.400024534.400024534.400024534.4000240\n'],
#  ['NYA1966-01-14535.450012535.450012535.450012535.450012535.4500120\n'],
#  ['NYA1966-01-17537.460022537.460022537.460022537.460022537.4600220\n'],
# ...

# %%
def dateConverter(dt):
    dt = dt.replace("-"," ")
    dt2 = pd.to_datetime(dt,format ='%Y %m %d',dayfirst=True)
    return dt2
